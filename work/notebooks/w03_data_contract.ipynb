# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# one row = one content per client per day , from jan 2025 to jun 2026 but it varies through each client so i need to check date per each client

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# features : clicks , imperessions , avg_position , session engagment , scroll events
#
# label : trend_pct and trend_direction
#
# Excluded: trend_pct and trend_direction , these are used to compute the label itself, so including them would leak the answer directly into the model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# ```
# # SELECT content_id, client_id, report_date, COUNT(*) as row_count
# FROM fact_content_daily_performance
# WHERE month = '2026-03'
# GROUP BY content_id, client_id, report_date
# HAVING COUNT(*) > 1
# LIMIT 5
# ```

# %% [markdown]
# ```
# # SELECT
#   COUNT(*) as total_rows,
#   MIN(report_date) as earliest_date,
#   MAX(report_date) as latest_date
# FROM fact_content_daily_performance
# WHERE month = '2026-03'
# ```

# %% [markdown]
# ```
# # SELECT COUNT(*) as available_rows
# FROM fact_content_daily_performance
# WHERE month = '2026-03'
#   AND ga4_data_available IS TRUE
# ```

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# This data can't give a balanced view across all clients — history length varies a lot, and a third of clients barely have usable data. Early GA4 rows can falsely look like zero engagement when really no data was collected yet, so any early-history stats risk being skewed. Also, the query table's time windows overlap the final months, so care is needed to avoid mixing future data into features

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
